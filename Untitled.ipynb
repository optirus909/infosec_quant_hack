# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import math
from random import randrange

from qiskit import IBMQ, BasicAer, Aer
from qiskit.providers.ibmq import least_busy
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, execute

from qiskit.visualization import plot_histogram

# %% [markdown]
# ## Функция оракул

# %%
import csv

def oracul(inputText):    
    csv_path = "letters.csv"
    with open(csv_path, "r") as f_obj:
        reader = csv.reader(f_obj)
        letters = {}
        for row in reader:
            letters[row[1]] = row[0]
    #print(letters)

    csv_path = "pairLetters.csv"

    with open(csv_path, "r") as f_obj:
        reader = csv.reader(f_obj)
        pairLetters = {}
        for row in reader:
            i = 0
            for data in row: 
                if i % 2 == 0:
                    data1 = data
                else:
                    pairLetters[data1] = data
                i += 1
    #print(pairLetters)
    inputText = inputText.lower()

    #print(inputText)

    j = 0
    
    alphaCount = 0
    
    targetText = ""

    for symbol in inputText:
        if ((symbol >= "a") and (symbol <= "z")):
            alphaCount += 1
        
        if ((symbol < "a") or (symbol > "z")) and (symbol != " ") and (symbol != ",") and (symbol != ".") and (symbol != ":") and (symbol != ";") and (symbol != "!") and (symbol != "?") and (symbol != '"') and (symbol != "'") and (symbol != "№") and  not ((symbol >= '0') or (symbol <= '9') ):
            j += 1
        else:
            targetText += symbol
            
    leng = len(inputText)
    
    if  j / leng > 0.2:
        return 0
        
    
    targetText = targetText.upper()
    
    #print(targetText)
    
    
    res = {i : targetText.count(i)*100/alphaCount for i in letters}
    #print(res)
    
    pairCount = 0
    
    for i in pairLetters:
        pairCount += targetText.count(i)
    
    res1 = {i : targetText.count(i)*100/pairCount for i in pairLetters}
    
    #print(res1)
    i = 0
    for symbol in letters:
        i += abs(float(letters[symbol]) - float(res[symbol]))
    print("Absolute error(one letter): {:.2f}".format(i))
    if i > 30:
        print("Probability: 0")
        return 0
    
    i = 0
    for symbol in pairLetters:
        i += abs(float(pairLetters[symbol]) - float(res1[symbol]))
        
    print("Absolute error(bigrams):    {:.2f}".format(i))
    if i > 50:
        print("Probability: 0")
        return 0
    print("Probability: 1")
    return 1

# %% [markdown]
# ### Проверка работы оракула на реальных текстах

# %% [markdown]
# __Связный текст__

# %%
with open("Shakespeare William. The Sonnets.txt", "r", encoding='windows-1252') as file:
        content = file.read()
        oracul(content)
# Out:
# Absolute error(one letter): 13.55
# Absolute error(bigrams):    37.02
# Probability: 1

# %% [markdown]
# __Случайный текст__

# %%
with open("bad.txt", "r") as file:
        content = file.read()
        oracul(content)
# Out:
# Absolute error(one letter): 83.92
# Probability: 0

# %% [markdown]
# ## Шифрование

# %%
import numpy as np
from Crypto.Cipher import DES
 

key_target = 12345678
# key_target = 12345670
print("Target key is", key_target)
key_target = str.encode(str(key_target))
 
def pad(text):
    while len(text) % 8 != 0:
        text += b' '
    return text
 
des_target = DES.new(key_target, DES.MODE_ECB)
text = open('Shakespeare William. The Sonnets.txt', 'rb').read().replace(b'\n', b' ').replace(b'\r', b' ')
padded_text = pad(text)
 
encrypted_text = des_target.encrypt(padded_text)
print("Text encrypted")
# Out:
# Target key is 12345670
# Text encrypted

# %% [markdown]
# ## Работа оракула в связке с шифрованием

# %% [markdown]
# __Расшифровка реальным ключем__

# %%
_ = decrypt_text(12345678)
# Out:
# Absolute error(one letter): 13.55
# Absolute error(bigrams):    37.02
# Probability: 1

# %% [markdown]
# __Расшифровка случайным ключем__

# %%
_ = decrypt_text( 12345671)
# Out:
# Absolute error(one letter): 71.08
# Probability: 0

# %% [markdown]
# ## Алгоритм поиска ключа

# %%
def decrypt_text(key):

    key = str.encode(str(key))
    des = DES.new(key, DES.MODE_ECB)

    data = des.decrypt(encrypted_text) # to oracle
    data = data.decode('latin-1')
    
    return oracul(data)

def run_grovers_algorthm(encrypted_text):
    num_qbits = 64
    # number of oracles
    k = 1

    # Set n qubits and n bits
    qr = QuantumRegister(num_qbits)
    cr = ClassicalRegister(num_qbits)

    if num_qbits > 3:
        aux = QuantumRegister(num_qbits-3)
        groverCircuit = QuantumCircuit(qr,cr, aux)
    else:
        aux = None
        groverCircuit = QuantumCircuit(qr,cr)
        
    def make_orcul_matrix(circuit, key):
        if circuit.size() > 0
            return [-1 if decrypt_text(key) else 1 for i in range(len(key))]
        return 0
        
    groverCircuit.h(qr)
    
    result = math.pi*math.sqrt((2**num_qbits)/k)/4 
    iterations = round(result)
    print("Number of inerations", iterations)

    for i in range(iterations-1):
        key = make_orcul_matrix(groverCircuit, key)
        groverCircuit.barrier(qr)
    
        groverCircuit.x(qr[1])
        groverCircuit.h(qr[num_qbits-1])
        groverCircuit.mct(qr[0:num_qbits-1], qr[num_qbits-1], aux)
        groverCircuit.h(qr[num_qbits-1])
        groverCircuit.x(qr[1])  

        groverCircuit.barrier(qr)
        groverCircuit.h(qr)
        groverCircuit.x(qr)
        groverCircuit.h(qr[num_qbits-1])
        groverCircuit.mct(qr[0:num_qbits-1], qr[num_qbits-1], aux)
        groverCircuit.h(qr[num_qbits-1])
        groverCircuit.x(qr)
        groverCircuit.h(qr)

    groverCircuit.barrier(qr)

    groverCircuit.draw(output="mpl")

groverCircuit.measure(qr,cr)
backend = BasicAer.get_backend('qasm_simulator')
shots = 5000
results = execute(groverCircuit, backend=backend, shots=shots).result()
answer = results.get_counts()
# Out:
# Number of inerations = 2385254615

# %%
plt.rcParams.update({'font.size': 15})
plt.figure(figsize=(12, 10))
plt.hist(data)
plt.ylabel("Probabilities")
plt.xticks([])
plt.annotate(int(key_target.decode('latin-1')), xy=(1, 1))
plt.show()
